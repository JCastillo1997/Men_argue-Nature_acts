# %%
def air_url(search_query):
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support import expected_conditions as EC
    from selenium.webdriver.support.ui import WebDriverWait
    from selenium.webdriver.common.keys import Keys
    import time

    driver = webdriver.Chrome()
    driver.implicitly_wait(10)  

    try:
        
        driver.get("https://www.iqair.com/")

        
        uk_link = driver.find_element(By.XPATH, "//li/a[contains(text(),'United Kingdom')]")
        uk_link.click()

        
        time.sleep(3)

        
        try:
            accept_button = driver.find_element(By.XPATH, "//button[contains(.,'Accept All Cookies')]")
            accept_button.click()
        except:
            print("Cookie consent pop-up not found or button not clickable")

        
        time.sleep(3)

        
        search_bar = driver.find_element(By.ID, "search-dropdown-input")
        search_bar.send_keys(search_query)
        search_bar.send_keys(Keys.TAB)

       
        wait = WebDriverWait(driver, 10)
        first_element = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "locality-item")))
        first_element.click()

        
        accept_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//span[contains(text(),'Accept All Cookies')]")))
        accept_button.click()

        
        current_url = driver.current_url
        
        return current_url

    except Exception as e:
        print("An error occurred:", e)
    finally:
        driver.quit()



    search_query = input("Please enter the search query: ")
    url = air_url(search_query)
    print("The URL of the page is:", url)

# %%
def air_url(search_query):
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support import expected_conditions as EC
    from selenium.webdriver.support.ui import WebDriverWait
    from selenium.webdriver.common.keys import Keys
    import time

    # Set Chrome options for headless mode
    chrome_options = Options()
    chrome_options.add_argument('--headless')  # Comment out this line to see the browser in action
    chrome_options.add_argument('--no-sandbox')
    chrome_options.add_argument('--disable-dev-shm-usage')

    driver = webdriver.Chrome(options=chrome_options)
    driver.implicitly_wait(10)

    try:
        
        driver.get("https://www.iqair.com/")

        
        uk_link = driver.find_element(By.XPATH, "//li/a[contains(text(),'United Kingdom')]")
        uk_link.click()

        
        time.sleep(3)

        
        try:
            accept_button = driver.find_element(By.XPATH, "//button[contains(.,'Accept All Cookies')]")
            accept_button.click()
        except:
            print("Cookie consent pop-up not found or button not clickable")

        
        time.sleep(3)

        
        search_bar = driver.find_element(By.ID, "search-dropdown-input")
        search_bar.send_keys(search_query)
        search_bar.send_keys(Keys.TAB)

       
        wait = WebDriverWait(driver, 10)
        first_element = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "locality-item")))
        first_element.click()

        
        accept_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//span[contains(text(),'Accept All Cookies')]")))
        accept_button.click()

        
        current_url = driver.current_url
        
        return current_url

    except Exception as e:
        print("An error occurred:", e)
    finally:
        driver.quit()



search_query = input("Please enter the search query: ")
url = air_url(search_query)
print("The URL of the page is:", url)
# Out:
# An error occurred: Message: stale element reference: stale element not found
#   (Session info: chrome-headless-shell=122.0.6261.112); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6EE31AD02+56930]
# 	(No symbol) [0x00007FF6EE28F602]
# 	(No symbol) [0x00007FF6EE1442E5]
# 	(No symbol) [0x00007FF6EE149261]
# 	(No symbol) [0x00007FF6EE14B6EB]
# 	(No symbol) [0x00007FF6EE14B7B0]
# 	(No symbol) [0x00007FF6EE18A5B4]
# 	(No symbol) [0x00007FF6EE18A6A2]
# 	(No symbol) [0x00007FF6EE1821C2]
# 	(No symbol) [0x00007FF6EE1ABC9A]
# 	(No symbol) [0x00007FF6EE17F09A]
# 	(No symbol) [0x00007FF6EE1ABEB0]
# 	(No symbol) [0x00007FF6EE1C81E2]
# 	(No symbol) [0x00007FF6EE1ABA43]
# 	(No symbol) [0x00007FF6EE17D438]
# 	(No symbol) [0x00007FF6EE17E4D1]
# 	GetHandleVerifier [0x00007FF6EE696F8D+3711213]
# 	GetHandleVerifier [0x00007FF6EE6F04CD+4077101]
# 	GetHandleVerifier [0x00007FF6EE6E865F+4044735]
# 	GetHandleVerifier [0x00007FF6EE3B9736+706710]
# 	(No symbol) [0x00007FF6EE29B8DF]
# 	(No symbol) [0x00007FF6EE296AC4]
# 	(No symbol) [0x00007FF6EE296C1C]
# 	(No symbol) [0x00007FF6EE2868D4]
# 	BaseThreadInitThunk [0x00007FF893CF257D+29]
# 	RtlUserThreadStart [0x00007FF89510AA58+40]
#
# The URL of the page is: None

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys

def air_url(search_query):
    chrome_options = Options()
    chrome_options.add_argument('--window-size=800,600')  # Set window size
    chrome_options.add_argument('--window-position=-2000,0')  # Set window position to off-screen
    # You can experiment with the window size and position based on your preference

    driver = webdriver.Chrome(options=chrome_options)
    driver.implicitly_wait(10)

    try:
        driver.get("https://www.iqair.com/")
        uk_link = driver.find_element(By.XPATH, "//li/a[contains(text(),'United Kingdom')]")
        uk_link.click()

        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[contains(.,'Accept All Cookies')]"))).click()

        search_bar = driver.find_element(By.ID, "search-dropdown-input")
        search_bar.send_keys(search_query)
        search_bar.send_keys(Keys.TAB)

        wait = WebDriverWait(driver, 10)
        first_element = wait.until(EC.element_to_be_clickable((By.CLASS_NAME, "locality-item")))
        first_element.click()

        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//span[contains(text(),'Accept All Cookies')]"))).click()

        current_url = driver.current_url
        return current_url

    except Exception as e:
        print("An error occurred:", e)
    finally:
        driver.quit()

search_query = input("Please enter the search query: ")
url = air_url(search_query)
print("The URL of the page is:", url)
# Out:
# An error occurred: Message: stale element reference: stale element not found
#   (Session info: chrome=122.0.6261.112); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6EE31AD02+56930]
# 	(No symbol) [0x00007FF6EE28F602]
# 	(No symbol) [0x00007FF6EE1442E5]
# 	(No symbol) [0x00007FF6EE149261]
# 	(No symbol) [0x00007FF6EE14B6EB]
# 	(No symbol) [0x00007FF6EE14B7B0]
# 	(No symbol) [0x00007FF6EE18A5B4]
# 	(No symbol) [0x00007FF6EE18A6A2]
# 	(No symbol) [0x00007FF6EE1821C2]
# 	(No symbol) [0x00007FF6EE1ABC9A]
# 	(No symbol) [0x00007FF6EE17F09A]
# 	(No symbol) [0x00007FF6EE1ABEB0]
# 	(No symbol) [0x00007FF6EE1C81E2]
# 	(No symbol) [0x00007FF6EE1ABA43]
# 	(No symbol) [0x00007FF6EE17D438]
# 	(No symbol) [0x00007FF6EE17E4D1]
# 	GetHandleVerifier [0x00007FF6EE696F8D+3711213]
# 	GetHandleVerifier [0x00007FF6EE6F04CD+4077101]
# 	GetHandleVerifier [0x00007FF6EE6E865F+4044735]
# 	GetHandleVerifier [0x00007FF6EE3B9736+706710]
# 	(No symbol) [0x00007FF6EE29B8DF]
# 	(No symbol) [0x00007FF6EE296AC4]
# 	(No symbol) [0x00007FF6EE296C1C]
# 	(No symbol) [0x00007FF6EE2868D4]
# 	BaseThreadInitThunk [0x00007FF893CF257D+29]
# 	RtlUserThreadStart [0x00007FF89510AA58+40]
#
# The URL of the page is: None

# %%
searach_query = input()
air_url(searach_query)
# Out:
# An error occurred: 'NoneType' object has no attribute 'is_displayed'
